# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('C:/Users/cg12680/OneDrive - Cerved/Documents/Python_Project/Performance_Account.csv',
                 index_col="Cod_Agente",
                 sep=";",
                 decimal = ",",
                 thousands = ".",
                 header=0)

# %%
df['Perc_visitate_>2'] = df['Perc_visitate_>2'].str.replace('%', '').astype(float)

# %%
df['Perc_visitate_>2'] = df['Perc_visitate_>2'].div(100)

# %%
df['Ticket_Medio'] = df['Ticket_Medio'].str.replace('€', '').astype(float)

# %%
df['Churn_NUM_Totale'] = df['Churn_NUM_Totale'].str.replace('%', '').astype(float)

# %%
df['Churn_NUM_Totale'] = df['Churn_NUM_Totale']*100

# %%
df['Churn_VAL_Totale'] = df['Churn_VAL_Totale'].str.replace('%', '').astype(float)

# %%
df['Churn_VAL_Totale'] = df['Churn_VAL_Totale'].div(100)

# %%
df.tail(10)
# Out:
#             MacroArea Enasarco_Dipendente    Cognome  MEDIA_PERFORMANCE_VT2  \
# Cod_Agente
# 5807                1          Dipendente     PREZZI                  -0.03
# 5820                1            Enasarco    MARIONI                  -0.07
# 5826                1          Dipendente     SARTEA                   0.03
# 5834                1          Dipendente   MONTAGNA                   0.06
# 5836                2          Dipendente    AUGELLO                   0.41
# 5843                1            Enasarco      ALAAM                   0.09
# 5860                1          Dipendente       IVOL                  -0.04
# 5861                2          Dipendente   APOLLONI                  -0.09
# 5942                2          Dipendente   MOCCALDI                   0.14
# 5959                2            Enasarco  SILVESTRI                   0.01
#
#             TARGET_PRESI_VT1 PEOPLE_SCORE_CLUSTER  Interpretazione_ruolo  \
# Cod_Agente
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 94 entries, 122 to 5959
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   MacroArea                  94 non-null     int64
#  1   Enasarco_Dipendente        94 non-null     object
#  2   Cognome                    94 non-null     object
#  3   MEDIA_PERFORMANCE_VT2      94 non-null     float64
#  4   TARGET_PRESI_VT1           94 non-null     int64
#  5   PEOPLE_SCORE_CLUSTER       94 non-null     object
#  6   Interpretazione_ruolo      94 non-null     int64
#  7   Competenza                 94 non-null     int64
#  8   Dialettica                 94 non-null     int64
#  9   Qualità_lavoro             94 non-null     int64
#  10  Risultati                  94 non-null     int64
#  11  Mindset                    94 non-null     int64
#  12  Aderenza_Vision            94 non-null     int64
# ...

# %%
sns.histplot(x=df["MEDIA_PERFORMANCE_VT2"], hue = df["Enasarco_Dipendente"])
# Out:
# <Axes: xlabel='MEDIA_PERFORMANCE_VT2', ylabel='Count'>

# %%
df_Enasarco = df[df["Enasarco_Dipendente"] == "Enasarco"]

# %%
df_agente = df.loc[df["Cognome"] == "PAVIGNANO", "MacroArea"]

# %%
df_agente
# Out:
# Cod_Agente
# 122    1
# Name: MacroArea, dtype: int64

# %%
df.groupby("Enasarco_Dipendente").size()
# Out:
# Enasarco_Dipendente
# Dipendente    21
# Enasarco      73
# dtype: int64

# %%
df.groupby("Enasarco_Dipendente").agg({"Ticket_Medio":"mean", "Tot_Visitate":"sum" })
# Out:
#                      Ticket_Medio  Tot_Visitate
# Enasarco_Dipendente
# Dipendente              16.583889        2030.0
# Enasarco                10.626070        9805.0

# %%
### VADO A RIEMPIRE I VALORI VUOTI CON LA MEDIA DEGLI ALTRI ###

# %%
df[df.isna().any(axis=1)]
# Out:
#             MacroArea Enasarco_Dipendente    Cognome  MEDIA_PERFORMANCE_VT2  \
# Cod_Agente
# 5552                2            Enasarco      PIPIA                   0.21
# 5661                1          Dipendente       MELE                   0.15
# 5719                2          Dipendente      GUIDA                   0.06
# 5742                2          Dipendente    LABANTI                  -0.35
# 5763                1            Enasarco  GIULIOTTO                   0.05
#
#             TARGET_PRESI_VT1 PEOPLE_SCORE_CLUSTER  Interpretazione_ruolo  \
# Cod_Agente
# 5552                       0                    D                      4
# 5661                       1                    A                      6
# 5719                       1                   B                       5
# 5742                       0                    D                      5
# 5763                       0                    E                      4
#
# ...

# %%
nan = {"Anagrafiche_visitate_>2": df["Anagrafiche_visitate_>2"].mean(),
       "Tot_Visitate": df["Tot_Visitate"].mean(),
       "Perc_visitate_>2": df["Perc_visitate_>2"].mean(),
       "Durata_media_opp_vinte_>5": df["Durata_media_opp_vinte_>5"].mean(),
       "Clienti_Tot": df["Clienti_Tot"].mean(),
       "Ticket_Medio": df["Clienti_Tot"].mean(),
       "Churn_NUM_Totale": df["Churn_NUM_Totale"].mean(),
       "Churn_VAL_Totale": df["Churn_VAL_Totale"].mean()}

# %%
df.fillna(nan, inplace=True)

# %%
df[df.isna().any(axis=1)]
# Out:
#             MacroArea Enasarco_Dipendente    Cognome  MEDIA_PERFORMANCE_VT2  \
# Cod_Agente
# 5552                2            Enasarco      PIPIA                   0.21
# 5661                1          Dipendente       MELE                   0.15
# 5719                2          Dipendente      GUIDA                   0.06
# 5742                2          Dipendente    LABANTI                  -0.35
# 5763                1            Enasarco  GIULIOTTO                   0.05
#
#             TARGET_PRESI_VT1 PEOPLE_SCORE_CLUSTER  Interpretazione_ruolo  \
# Cod_Agente
# 5552                       0                    D                      4
# 5661                       1                    A                      6
# 5719                       1                   B                       5
# 5742                       0                    D                      5
# 5763                       0                    E                      4
#
# ...

# %%
df_dropna = df.copy()  ### faccio una copia del DB

# %%
df_dropna.dropna(axis=1) ### scarto tutte le colonne (axis=1) con almeno un valore NA
# Out:
#             MacroArea Enasarco_Dipendente    Cognome  MEDIA_PERFORMANCE_VT2  \
# Cod_Agente
# 122                 1            Enasarco  PAVIGNANO                  -0.07
# 168                 2            Enasarco      CONTE                  -0.02
# 219                 1            Enasarco  BENVENUTO                   0.03
# 255                 2          Dipendente     PISANI                  -0.08
# 298                 2            Enasarco     DI DIO                   0.09
# ...               ...                 ...        ...                    ...
# 5843                1            Enasarco      ALAAM                   0.09
# 5860                1          Dipendente       IVOL                  -0.04
# 5861                2          Dipendente   APOLLONI                  -0.09
# 5942                2          Dipendente   MOCCALDI                   0.14
# 5959                2            Enasarco  SILVESTRI                   0.01
#
# ...

# %%
sns.lmplot(data=df, x="Churn_VAL_Totale", y="MEDIA_PERFORMANCE_VT2", hue="Enasarco_Dipendente")
# Out:
# C:\Users\cg12680\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.describe()
# Out:
#        MacroArea  MEDIA_PERFORMANCE_VT2  TARGET_PRESI_VT1  \
# count  94.000000              94.000000         94.000000
# mean    1.521277               0.032660          0.180851
# std     0.502226               0.152824          0.386959
# min     1.000000              -0.350000          0.000000
# 25%     1.000000              -0.047500          0.000000
# 50%     2.000000               0.010000          0.000000
# 75%     2.000000               0.060000          0.000000
# max     2.000000               0.890000          1.000000
#
#        Interpretazione_ruolo  Competenza  Dialettica  Qualità_lavoro  \
# count              94.000000   94.000000   94.000000       94.000000
# mean                4.914894    5.276596    4.936170        4.851064
# std                 1.064173    0.896879    0.970628        1.057055
# min                 2.000000    3.000000    2.000000        3.000000
# 25%                 4.000000    5.000000    4.000000        4.000000
# ...
